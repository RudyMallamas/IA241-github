# %%
# !pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 4.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel('s3://ia-241-mallamas/Diamonds.xls')

df.head(10)
# Out:
#    IDNO  WEIGHT COLOR CLARITY RATER  PRICE
# 0     1    0.30     D     VS2   GIA   1302
# 1     2    0.30     E     VS1   GIA   1510
# 2     3    0.30     G    VVS1   GIA   1510
# 3     4    0.30     G     VS1   GIA   1260
# 4     5    0.31     D     VS1   GIA   1641
# 5     6    0.31     E     VS1   GIA   1555
# 6     7    0.31     F     VS1   GIA   1427
# 7     8    0.31     G    VVS2   GIA   1427
# 8     9    0.31     H     VS2   GIA   1126
# 9    10    0.31     I     VS1   GIA   1126

# %%
df.tail(10)
# Out:
#      IDNO  WEIGHT COLOR CLARITY RATER  PRICE
# 298   299    1.01     G    VVS2   HRD   9993
# 299   300    1.01     G     VS2   HRD   9293
# 300   301    1.01     H    VVS2   HRD   9433
# 301   302    1.01     H     VS1   HRD   9153
# 302   303    1.01     I    VVS1   HRD   8873
# 303   304    1.01     I     VS1   HRD   8175
# 304   305    1.02     F    VVS2   HRD  10796
# 305   306    1.06     H    VVS2   HRD   9890
# 306   307    1.02     H     VS2   HRD   8959
# 307   308    1.09     I    VVS2   HRD   9107

# %%
df.describe()
# Out:
#              IDNO      WEIGHT         PRICE
# count  308.000000  308.000000    308.000000
# mean   154.500000    0.630909   5019.483766
# std     89.056162    0.277183   3403.115715
# min      1.000000    0.180000    638.000000
# 25%     77.750000    0.350000   1625.000000
# 50%    154.500000    0.620000   4215.000000
# 75%    231.250000    0.850000   7446.000000
# max    308.000000    1.100000  16008.000000

# %%
df['PRICE']
# Out:
# 0       1302
# 1       1510
# 2       1510
# 3       1260
# 4       1641
#        ...
# 303     8175
# 304    10796
# 305     9890
# 306     8959
# 307     9107
# Name: PRICE, Length: 308, dtype: int64

# %%
df['RATER']
# Out:
# 0      GIA
# 1      GIA
# 2      GIA
# 3      GIA
# 4      GIA
#       ...
# 303    HRD
# 304    HRD
# 305    HRD
# 306    HRD
# 307    HRD
# Name: RATER, Length: 308, dtype: object

# %%
df[0:5]
# Out:
#    IDNO  WEIGHT COLOR CLARITY RATER  PRICE
# 0     1    0.30     D     VS2   GIA   1302
# 1     2    0.30     E     VS1   GIA   1510
# 2     3    0.30     G    VVS1   GIA   1510
# 3     4    0.30     G     VS1   GIA   1260
# 4     5    0.31     D     VS1   GIA   1641

# %%
df[:10]
# Out:
#    IDNO  WEIGHT COLOR CLARITY RATER  PRICE
# 0     1    0.30     D     VS2   GIA   1302
# 1     2    0.30     E     VS1   GIA   1510
# 2     3    0.30     G    VVS1   GIA   1510
# 3     4    0.30     G     VS1   GIA   1260
# 4     5    0.31     D     VS1   GIA   1641
# 5     6    0.31     E     VS1   GIA   1555
# 6     7    0.31     F     VS1   GIA   1427
# 7     8    0.31     G    VVS2   GIA   1427
# 8     9    0.31     H     VS2   GIA   1126
# 9    10    0.31     I     VS1   GIA   1126

# %%
df.loc[df['PRICE'] > 1500]
# Out:
#      IDNO  WEIGHT COLOR CLARITY RATER  PRICE
# 1       2    0.30     E     VS1   GIA   1510
# 2       3    0.30     G    VVS1   GIA   1510
# 4       5    0.31     D     VS1   GIA   1641
# 5       6    0.31     E     VS1   GIA   1555
# 14     15    0.34     E     VS1   GIA   1693
# ..    ...     ...   ...     ...   ...    ...
# 303   304    1.01     I     VS1   HRD   8175
# 304   305    1.02     F    VVS2   HRD  10796
# 305   306    1.06     H    VVS2   HRD   9890
# 306   307    1.02     H     VS2   HRD   8959
# 307   308    1.09     I    VVS2   HRD   9107
#
# [245 rows x 6 columns]

# %%
df['COLOR'].count()
# Out:
# 308

# %%
df['COLOR'].value_counts()
# Out:
# F    82
# G    65
# H    61
# E    44
# I    40
# D    16
# Name: COLOR, dtype: int64

# %%
df.mean()
# Out:
# /tmp/ipykernel_10951/3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# IDNO       154.500000
# WEIGHT       0.630909
# PRICE     5019.483766
# dtype: float64

# %%
df['WEIGHT'].min()
# Out:
# 0.18

# %%
df.groupby('COLOR').mean()
# Out:
# /tmp/ipykernel_10951/1353082583.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('COLOR').mean()
#              IDNO    WEIGHT        PRICE
# COLOR
# D      128.812500  0.638125  7099.875000
# E      140.590909  0.623182  5507.931818
# F      149.012195  0.592927  4786.402439
# G      159.492308  0.580769  4426.184615
# H      165.704918  0.673443  4965.016393
# I      166.125000  0.731000  5175.025000

# %%
df.groupby('COLOR').mean()['PRICE']
# Out:
# /tmp/ipykernel_10951/1762345461.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('COLOR').mean()['PRICE']
# COLOR
# D    7099.875000
# E    5507.931818
# F    4786.402439
# G    4426.184615
# H    4965.016393
# I    5175.025000
# Name: PRICE, dtype: float64

# %%
from scipy import stats

# %%
result = stats.linregress(df['PRICE'], df['WEIGHT'])

# %%
print(result.slope)
print(result.intercept)
# Out:
# 7.694778091374687e-05
# 0.24467095376482606

# %%
print(0.5 * result.slope+result.intercept) #prediction
# Out:
# 0.24470942765528295
